# %% [markdown]
# <a href="https://colab.research.google.com/github/Crashed-cpu/aws-ml-py/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello
